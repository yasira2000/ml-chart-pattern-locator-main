# %%
import pandas as pd
import numpy as np

# %%
# load a sample OHLC data from OHLC data folders file
from utils.patternLocating import locate_patterns


ohlc_data = pd.read_csv('OHLC data/AAPL.csv')
# select a random range that is larger than 10 days
ohlc_data_sample = ohlc_data.iloc[50:75]
# pattern_located = locate_patterns(ohlc_data_sample,enable_plotting =True)
pattern_located = locate_patterns(ohlc_data_sample)
# Out:
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done  20 out of  25 | elapsed:   13.6s remaining:    3.3s
# [Parallel(n_jobs=16)]: Done  25 out of  25 | elapsed:   13.8s finished
# Clustered windows dataframe is empty
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done  20 out of  25 | elapsed:    3.5s remaining:    0.8s
# [Parallel(n_jobs=16)]: Done  25 out of  25 | elapsed:    3.7s finished
# Clustered windows dataframe is empty
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done  20 out of  25 | elapsed:    3.5s remaining:    0.8s
# [Parallel(n_jobs=16)]: Done  25 out of  25 | elapsed:    3.7s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done  20 out of  25 | elapsed:    3.5s remaining:    0.8s
# ...

# %%
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done  20 out of  25 | elapsed:   15.2s remaining:    3.7s
# [Parallel(n_jobs=16)]: Done  25 out of  25 | elapsed:   15.6s finished
# Clustered windows dataframe is empty
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done  20 out of  25 | elapsed:    4.9s remaining:    1.2s
# [Parallel(n_jobs=16)]: Done  25 out of  25 | elapsed:    5.2s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# Clustered windows dataframe is empty
# [Parallel(n_jobs=16)]: Done  20 out of  25 | elapsed:    4.6s remaining:    1.1s
# [Parallel(n_jobs=16)]: Done  25 out of  25 | elapsed:    5.0s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done  20 out of  25 | elapsed:    4.6s remaining:    1.1s
# [Parallel(n_jobs=16)]: Done  25 out of  25 | elapsed:    5.0s finished

# %%
pattern_located
# Out:
#   Chart Pattern  Cluster      Start        End  Seg_Start    Seg_End  \
# 0    Double Top        0 2019-03-15 2019-03-27 2019-03-15 2019-04-18
# 1    Double Top        1 2019-04-05 2019-04-18 2019-03-15 2019-04-18
#
#    Avg_Probability Calc_Start   Calc_End  Window_Size
# 0         0.914487 2019-03-15 2019-03-27           12
# 1         0.943405 2019-04-05 2019-04-18           12
